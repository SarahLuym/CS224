# %% [markdown]
# ## Set-up Code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CS224n/a5/src'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['utils.py', 'trainer.py', 'model.py', 'attention.py', 'london_baseline.py', 'run.py', 'dataset.py', '.DS_Store', '__pycache__']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %%
# !python /content/drive/MyDrive/CS224n/a5/src/run.py finetune vanilla /content/drive/MyDrive/CS224n/a5/wiki.txt  --reading_params_path /content/drive/MyDrive/CS224n/a5/vanilla.pretrain.params  --writing_params_path /content/drive/MyDrive/CS224n/a5/vanilla.finetune.params  --finetune_corpus_path /content/drive/MyDrive/CS224n/a5/birth_places_train.tsv
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 7: train loss 0.69907. lr 5.999844e-04: 100% 8/8 [00:02<00:00,  3.40it/s]
# epoch 2 iter 7: train loss 0.55625. lr 5.999351e-04: 100% 8/8 [00:02<00:00,  3.61it/s]
# epoch 3 iter 7: train loss 0.46916. lr 5.998521e-04: 100% 8/8 [00:02<00:00,  3.56it/s]
# epoch 4 iter 7: train loss 0.39795. lr 5.997352e-04: 100% 8/8 [00:02<00:00,  3.55it/s]
# epoch 5 iter 7: train loss 0.33724. lr 5.995847e-04: 100% 8/8 [00:02<00:00,  3.53it/s]
# ...

# %%
# !python /content/drive/MyDrive/CS224n/a5/src/run.py evaluate vanilla /content/drive/MyDrive/CS224n/a5/wiki.txt  --reading_params_path /content/drive/MyDrive/CS224n/a5/vanilla.finetune.params  --eval_corpus_path /content/drive/MyDrive/CS224n/a5/birth_dev.tsv  --outputs_path /content/drive/MyDrive/CS224n/a5/vanilla.pretrain.dev.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CS224n/a5/src/run.py", line 163, in <module>
#     pred = utils.sample(model, x, 32, sample=False)[0]
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/CS224n/a5/src/utils.py", line 37, in sample
#     logits, _ = model(x_cond)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/drive/MyDrive/CS224n/a5/src/model.py", line 100, in forward
#     token_embeddings = self.tok_emb(idx) # each index maps to a (learnable) vector
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
# ...
