# %% [markdown]
# ## Set-up Code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CS224n/a5/src'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['trainer.py', 'london_baseline.py', 'dataset.py', '.DS_Store', 'utils.py', 'model.py', '__pycache__', 'attention.py', 'run.py']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %%
# !python /content/drive/MyDrive/CS224n/a5/src/run.py pretrain synthesizer /content/drive/MyDrive/CS224n/a5/wiki.txt  --writing_params_path /content/drive/MyDrive/CS224n/a5/synthesizer.pretrain.params
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 22: train loss 3.46928. lr 5.999655e-03: 100% 23/23 [00:03<00:00,  6.52it/s]
# epoch 2 iter 22: train loss 3.31139. lr 5.998582e-03: 100% 23/23 [00:03<00:00,  6.89it/s]
# epoch 3 iter 22: train loss 3.05287. lr 5.996780e-03: 100% 23/23 [00:03<00:00,  6.82it/s]
# epoch 4 iter 22: train loss 2.88723. lr 5.994250e-03: 100% 23/23 [00:03<00:00,  6.78it/s]
# epoch 5 iter 22: train loss 2.81956. lr 5.990993e-03: 100% 23/23 [00:03<00:00,  6.82it/s]
# ...

# %%
# !python /content/drive/MyDrive/CS224n/a5/src/run.py finetune synthesizer /content/drive/MyDrive/CS224n/a5/wiki.txt  --reading_params_path /content/drive/MyDrive/CS224n/a5/synthesizer.pretrain.params  --writing_params_path /content/drive/MyDrive/CS224n/a5/synthesizer.finetune.params  --finetune_corpus_path /content/drive/MyDrive/CS224n/a5/birth_places_train.tsv
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 7: train loss 0.78230. lr 5.999844e-04: 100% 8/8 [00:02<00:00,  3.67it/s]
# epoch 2 iter 7: train loss 0.63051. lr 5.999351e-04: 100% 8/8 [00:02<00:00,  3.84it/s]
# epoch 3 iter 7: train loss 0.58489. lr 5.998521e-04: 100% 8/8 [00:02<00:00,  3.80it/s]
# epoch 4 iter 7: train loss 0.54783. lr 5.997352e-04: 100% 8/8 [00:02<00:00,  3.84it/s]
# epoch 5 iter 7: train loss 0.49684. lr 5.995847e-04: 100% 8/8 [00:02<00:00,  3.87it/s]
# ...

# %%
# !python /content/drive/MyDrive/CS224n/a5/src/run.py evaluate synthesizer /content/drive/MyDrive/CS224n/a5/wiki.txt  --reading_params_path /content/drive/MyDrive/CS224n/a5/synthesizer.finetune.params  --eval_corpus_path /content/drive/MyDrive/CS224n/a5/birth_dev.tsv  --outputs_path /content/drive/MyDrive/CS224n/a5/synthesizer.pretrain.dev.predictions
# Out:
# /content/drive/MyDrive/CS224n/a5/wiki.txt
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# 492it [00:46, 10.66it/s]
# Correct: 53.0 out of 492.0: 10.772357723577237%
